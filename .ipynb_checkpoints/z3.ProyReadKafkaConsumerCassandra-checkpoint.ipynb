# %%
from pyspark.sql.functions import from_json, col, to_timestamp
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.sql import SparkSession

# %%
def write_to_cassandra(target_df, batch_id):
    target_df.write \
        .format("org.apache.spark.sql.cassandra") \
        .option("keyspace", "spark_db") \
        .option("table", "customer_search") \
        .mode("append") \
        .save()
    target_df.show()

# %%
spark = SparkSession \
        .builder \
        .master("local[3]") \
        .appName("Stream Table Join Demo") \
        .config("spark.streaming.stopGracefullyOnShutdown", "true") \
        .config("spark.sql.shuffle.partitions", 2) \
        .config("spark.cassandra.connection.host", "localhost") \
        .config("spark.cassandra.connection.port", "9042") \
        .config("spark.sql.extensions", "com.datastax.spark.connector.CassandraSparkExtensions") \
        .config("spark.sql.catalog.lh", "com.datastax.spark.connector.datasource.CassandraCatalog") \
        .getOrCreate()

# %%
search_schema = StructType([
        StructField("id", StringType()),
        StructField("customer_id", StringType()),
        StructField("customer_name", StringType()),
        StructField("product_searched", StringType()),
        StructField("search_date", StringType()),
        StructField("country_name", StringType()),
        StructField("state", StringType())
    ])

# %%
kafka_source_df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", "localhost:9092") \
        .option("subscribe", "product-customer-qty") \
        .option("startingOffsets", "earliest") \
        .option("failOnDataLoss", False) \
        .load()

# %%
value_df = kafka_source_df.select(from_json(col("value").cast("string"), search_schema).alias("value"))

# %%
prod_customer_df = value_df.select("value.*") \
        .withColumn("search_date", to_timestamp(col("search_date"), "yyyy-MM-dd HH:mm:ss"))

# %%
prod_customer_df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- product_searched: string (nullable = true)
#  |-- search_date: timestamp (nullable = true)
#  |-- country_name: string (nullable = true)
#  |-- state: string (nullable = true)

# %%
output_df = prod_customer_df.select(col("id"), col("customer_id"), col("customer_name"), col("product_searched"), 
                             col("search_date"), col("country_name"),col("state"))
#                             .withColumn("idNum", col("customer_id").cast(IntegerType())) \
#                             .withColumn("id",    col("id").cast(IntegerType()))

# %%
# #to view the data in the console
notification_writer_query = output_df.writeStream \
        .format("console") \
        .outputMode("append") \
        .option("truncate", "false") \
        .option("checkpointLocation", "./checkpoints/cassandra-proj/") \
        .start()

# # notification_writer_query.awaitTermination()

# %%
#Aggregations Val

# agg_output_df = output_df.groupBy("country_name", "product_searched")\
#       .agg(count("id")).alias("search_qty")

# agg_search_locations_df = output_df.groupBy("name")\
#      .agg(sum("idNum"), count("id"))

# %%
# output_query = output_df.writeStream \
output_query = output_df.writeStream \
        .foreachBatch(write_to_cassandra) \
        .outputMode("update") \
        .option("checkpointLocation", "./checkpoints/cassandra-proj") \
        .trigger(processingTime="1 minute") \
        .start()

# %%
output_query.awaitTermination()
# Out:
# +---+-----------+-------------+--------------------+-------------------+------------+----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|           state|
# +---+-----------+-------------+--------------------+-------------------+------------+----------------+
# | 36|          9|          Jox|Gildan Mens Assor...|2023-04-28 20:27:37|    Suriname|Coronie District|
# +---+-----------+-------------+--------------------+-------------------+------------+----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
# | 37|          8|      Maryina|         Water Shoes|2023-04-28 20:28:07|    Tanzania|Zanzibar North|
# | 38|          6|       Emilio|Samsung Galaxy s2...|2023-04-28 20:28:37|Turkmenistan|   Mary Region|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | 39|          1|       Johnny|        Creatine|2023-04-28 20:29:07|  Azerbaijan|Kurdamir District|
# | 40|          5|        Maria|        Creatine|2023-04-28 20:29:37|        Chad|        N'Djamena|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|  state|
# +---+-----------+-------------+--------------------+-------------------+------------+-------+
# | 41|          5|        Maria|         Water Shoes|2023-04-28 20:30:07|       Egypt|Beheira|
# | 42|          4|         John|Samsung Galaxy s2...|2023-04-28 20:30:37|       Malta|  Mġarr|
# +---+-----------+-------------+--------------------+-------------------+------------+-------+
#
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
# | 43|          3|      EmilyAn|       Samsung Tab|2023-04-28 20:31:07| The Bahamas|        South Andros|
# | 44|         13|        Mario|Asus Gaming Laptop|2023-04-28 20:31:37|    Slovenia|Ivančna Gorica Mu...|
# +---+-----------+-------------+------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
# | 45|         17|       Marcia|Samsung Galaxy s22|2023-04-28 20:32:07|      Greece|Kozani Prefecture|
# | 46|          2|     Marielys|   Ninja Air Frier|2023-04-28 20:32:37| Netherlands|       Gelderland|
# +---+-----------+-------------+------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-----+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|state|
# +---+-----------+-------------+--------------------+-------------------+------------+-----+
# | 47|          6|       Emilio|  Samsung Galaxy s22|2023-04-28 20:33:07|       Yemen|  Ibb|
# | 48|         11|       Emilia|Samsung Galaxy s2...|2023-04-28 20:33:37|      Turkey|Adana|
# +---+-----------+-------------+--------------------+-------------------+------------+-----+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|   state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------+
# | 49|         11|       Emilia|Workout Leggins f...|2023-04-28 20:34:07|       Kenya|    Embu|
# | 50|         20|     JohnEric|  Samsung Galaxy s22|2023-04-28 20:34:37| Philippines|Mimaropa|
# +---+-----------+-------------+--------------------+-------------------+------------+--------+
#
# +---+-----------+-------------+----------------+-------------------+------------+---------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|    state|
# +---+-----------+-------------+----------------+-------------------+------------+---------+
# | 51|         15|       Martha| Ninja Air Frier|2023-04-28 20:35:07|       Italy|Agrigento|
# | 52|          2|     Marielys| Apple Iphone 14|2023-04-28 20:35:37|       Italy|     Como|
# +---+-----------+-------------+----------------+-------------------+------------+---------+
#
# +---+-----------+-------------+----------------+-------------------+------------+------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|             state|
# +---+-----------+-------------+----------------+-------------------+------------+------------------+
# | 53|          9|          Jox|            Roku|2023-04-28 20:36:07|    Thailand|       Suphan Buri|
# | 54|         16|       Marius| Ninja Air Frier|2023-04-28 20:36:37|       Congo|Cuvette Department|
# +---+-----------+-------------+----------------+-------------------+------------+------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | 55|         20|     JohnEric| Ninja Air Frier|2023-04-28 20:37:07|     Morocco|Tanger-Tétouan-Al...|
# | 56|         12|       Jowell|     Samsung Tab|2023-04-28 20:37:37|     Algeria|            Ghardaïa|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# | 57|         10|        Emona|            Roku|2023-04-28 20:38:07|      Tuvalu|      Funafuti|
# | 58|          6|       Emilio|      Apple Ipad|2023-04-28 20:38:37|     Finland|Finland Proper|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
# | 59|         18|       Johvay|                Roku|2023-04-28 20:39:07|        Cuba|Matanzas Province|
# | 60|         14|       Mirtha|Samsung Galaxy s2...|2023-04-28 20:39:37|     Romania|     Mureș County|
# +---+-----------+-------------+--------------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+---------------+-------------------+
# | id|customer_id|customer_name|product_searched|        search_date|   country_name|              state|
# +---+-----------+-------------+----------------+-------------------+---------------+-------------------+
# | 61|         10|        Emona|            Roku|2023-04-28 20:40:07|North Macedonia|Prilep Municipality|
# | 62|         13|        Mario|     Bed Pillows|2023-04-28 20:40:37|       Maldives|          Raa Atoll|
# +---+-----------+-------------+----------------+-------------------+---------------+-------------------+
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | 63|         14|       Mirtha|            Roku|2023-04-28 20:41:07|Sierra Leone|Southern Province|
# | 64|          8|      Maryina|     Water Shoes|2023-04-28 20:41:37|     Andorra|           Ordino|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+----------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|    country_name|            state|
# +---+-----------+-------------+----------------+-------------------+----------------+-----------------+
# | 65|          2|     Marielys|     Water Shoes|2023-04-28 20:42:07|Papua new Guinea|     Port Moresby|
# | 66|         12|       Jowell|        Creatine|2023-04-28 20:42:37|           India|Jammu and Kashmir|
# +---+-----------+-------------+----------------+-------------------+----------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|state|
# +---+-----------+-------------+----------------+-------------------+------------+-----+
# | 67|          6|       Emilio| Ninja Air Frier|2023-04-28 20:43:07|     Nigeria|  Edo|
# | 68|          8|      Maryina|     Water Shoes|2023-04-28 20:43:37|       Malta|Mdina|
# +---+-----------+-------------+----------------+-------------------+------------+-----+
#
# +---+-----------+-------------+----------------+-------------------+-------------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|       country_name|               state|
# +---+-----------+-------------+----------------+-------------------+-------------------+--------------------+
# | 69|          7|         Emil|        Creatine|2023-04-28 20:44:07|             Panama|Bocas del Toro Pr...|
# | 70|          4|         John| Apple Iphone 14|2023-04-28 20:44:37|Trinidad And Tobago|Penal-Debe Region...|
# +---+-----------+-------------+----------------+-------------------+-------------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|   state|
# +---+-----------+-------------+----------------+-------------------+------------+--------+
# | 71|          3|      EmilyAn|      Apple Ipad|2023-04-28 20:45:07|        null|    null|
# | 72|         17|       Marcia|     Samsung Tab|2023-04-28 20:45:37|      Turkey|Tekirdağ|
# +---+-----------+-------------+----------------+-------------------+------------+--------+
#
# +---+-----------+-------------+--------------------+-------------------+--------------+------+
# | id|customer_id|customer_name|    product_searched|        search_date|  country_name| state|
# +---+-----------+-------------+--------------------+-------------------+--------------+------+
# | 73|          4|         John|           Bed Sheet|2023-04-28 20:46:07|    Cape Verde|   Sal|
# | 74|         13|        Mario|Gildan Mens Assor...|2023-04-28 20:46:37|United Kingdom|Bolton|
# +---+-----------+-------------+--------------------+-------------------+--------------+------+
#
# +---+-----------+-------------+--------------------+-------------------+--------------+-------+
# | id|customer_id|customer_name|    product_searched|        search_date|  country_name|  state|
# +---+-----------+-------------+--------------------+-------------------+--------------+-------+
# | 75|          5|        Maria|Workout Leggins f...|2023-04-28 20:47:07|United Kingdom| Dorset|
# | 76|         14|       Mirtha|  Asus Gaming Laptop|2023-04-28 20:47:37|   Philippines|Isabela|
# +---+-----------+-------------+--------------------+-------------------+--------------+-------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|         state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
# | 77|         15|       Martha|      Air Jordan|2023-04-28 20:48:07|     Belgium|         Namur|
# | 78|          2|     Marielys|      Apple Ipad|2023-04-28 20:48:38|      Uganda|Luuka District|
# +---+-----------+-------------+----------------+-------------------+------------+--------------+
#
# +---+-----------+-------------+--------------------+-------------------+-------------+-------------+
# | id|customer_id|customer_name|    product_searched|        search_date| country_name|        state|
# +---+-----------+-------------+--------------------+-------------------+-------------+-------------+
# | 79|         11|       Emilia|Workout Leggins f...|2023-04-28 20:49:08|        India|    Jharkhand|
# | 80|          4|         John|     Ninja Air Frier|2023-04-28 20:49:38|Guinea-Bissau|Bolama Region|
# +---+-----------+-------------+--------------------+-------------------+-------------+-------------+
#
# +---+-----------+-------------+------------------+-------------------+-------------------+--------------+
# | id|customer_id|customer_name|  product_searched|        search_date|       country_name|         state|
# +---+-----------+-------------+------------------+-------------------+-------------------+--------------+
# | 81|         16|       Marius|              Roku|2023-04-28 20:50:08|      United States| Jarvis Island|
# | 82|          9|          Jox|Samsung Galaxy s22|2023-04-28 20:50:38|Trinidad And Tobago|Western Tobago|
# +---+-----------+-------------+------------------+-------------------+-------------------+--------------+
#
# +---+-----------+-------------+--------------------+-------------------+--------------+---------------+
# | id|customer_id|customer_name|    product_searched|        search_date|  country_name|          state|
# +---+-----------+-------------+--------------------+-------------------+--------------+---------------+
# | 83|          1|       Johnny|Samsung Galaxy s2...|2023-04-28 20:51:08|United Kingdom|         Torbay|
# | 84|         12|       Jowell|         Samsung Tab|2023-04-28 20:51:38|       Albania|Durrës District|
# +---+-----------+-------------+--------------------+-------------------+--------------+---------------+
#
# +---+-----------+-------------+----------------+-------------------+-------------+--------+
# | id|customer_id|customer_name|product_searched|        search_date| country_name|   state|
# +---+-----------+-------------+----------------+-------------------+-------------+--------+
# | 85|          1|       Johnny| Apple Iphone 14|2023-04-28 20:52:08|       Turkey|  Yozgat|
# | 86|          3|      EmilyAn|     Samsung Tab|2023-04-28 20:52:38|United States|Maryland|
# +---+-----------+-------------+----------------+-------------------+-------------+--------+
#
# +---+-----------+-------------+------------------+-------------------+------------+---------------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|          state|
# +---+-----------+-------------+------------------+-------------------+------------+---------------+
# | 87|         15|       Martha|Asus Gaming Laptop|2023-04-28 20:53:08|       Kenya|       Homa Bay|
# | 88|          2|     Marielys|       Bed Pillows|2023-04-28 20:53:38|  Mozambique|Sofala Province|
# +---+-----------+-------------+------------------+-------------------+------------+---------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|state|
# +---+-----------+-------------+----------------+-------------------+------------+-----+
# | 89|         18|       Johvay|            Roku|2023-04-28 20:54:08|    Colombia|Sucre|
# | 90|          5|        Maria|      Air Jordan|2023-04-28 20:54:38|     Germany|Hesse|
# +---+-----------+-------------+----------------+-------------------+------------+-----+
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|  country_name|               state|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
# | 91|         16|       Marius|      Air Jordan|2023-04-28 20:55:08|      Slovenia|Žirovnica Municip...|
# | 92|         20|     JohnEric|       Bed Sheet|2023-04-28 20:55:38|United Kingdom|Coleraine Borough...|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+--------------------+--------------+
# | id|customer_id|customer_name|product_searched|        search_date|        country_name|         state|
# +---+-----------+-------------+----------------+-------------------+--------------------+--------------+
# | 93|          9|          Jox|     Bed Pillows|2023-04-28 20:56:08|              Angola|Huíla Province|
# | 94|          7|         Emil|     Bed Pillows|2023-04-28 20:56:38|United Arab Emirates|      Fujairah|
# +---+-----------+-------------+----------------+-------------------+--------------------+--------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|        state|
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
# | 95|         19|    Johnathan|      Air Jordan|2023-04-28 20:57:08|  Uzbekistan|     Tashkent|
# | 96|         19|    Johnathan|            Roku|2023-04-28 20:57:38|      Uganda|Arua District|
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
#
# +---+-----------+-------------+--------------------+-------------------+---------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|   country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+---------------+--------------------+
# | 97|          4|         John|Gildan Mens Assor...|2023-04-28 20:58:08|North Macedonia|Oslomej Municipality|
# | 98|         12|       Jowell|                Roku|2023-04-28 20:58:38|        Vietnam|          Bình Dương|
# +---+-----------+-------------+--------------------+-------------------+---------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
# | 99|          9|          Jox|Workout Leggins f...|2023-04-28 20:59:08|     Finland|           Satakunta|
# |100|          3|      EmilyAn|  Asus Gaming Laptop|2023-04-28 20:59:38|      Poland|Greater Poland Vo...|
# +---+-----------+-------------+--------------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+----------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|     state|
# +---+-----------+-------------+----------------+-------------------+------------+----------+
# |101|          5|        Maria|     Samsung Tab|2023-04-28 21:00:08|    Colombia| Atlántico|
# |102|          4|         John| Ninja Air Frier|2023-04-28 21:00:38| Philippines|Ilocos Sur|
# +---+-----------+-------------+----------------+-------------------+------------+----------+
#
# +---+-----------+-------------+----------------+-------------------+------------+------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|       state|
# +---+-----------+-------------+----------------+-------------------+------------+------------+
# |103|          9|          Jox|      Air Jordan|2023-04-28 21:01:08|      France|Haute-Savoie|
# |104|          9|          Jox|      Apple Ipad|2023-04-28 21:01:38|     Romania| Gorj County|
# +---+-----------+-------------+----------------+-------------------+------------+------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|             state|
# +---+-----------+-------------+----------------+-------------------+------------+------------------+
# |105|          3|      EmilyAn|            Roku|2023-04-28 21:02:08|       Palau|          Ngchesar|
# |106|          2|     Marielys|     Bed Pillows|2023-04-28 21:02:38|  East Timor|Aileu municipality|
# +---+-----------+-------------+----------------+-------------------+------------+------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# |107|          1|       Johnny|     Samsung Tab|2023-04-28 21:03:08|    Paraguay|Cordillera Depart...|
# |108|          5|        Maria| Apple Iphone 14|2023-04-28 21:03:38|    Cameroon|           Northwest|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+--------------------+-------------------+--------------+---------+
# | id|customer_id|customer_name|    product_searched|        search_date|  country_name|    state|
# +---+-----------+-------------+--------------------+-------------------+--------------+---------+
# |109|          5|        Maria|Samsung Galaxy s2...|2023-04-28 21:04:08|United Kingdom|Hampshire|
# |110|          2|     Marielys|         Bed Pillows|2023-04-28 21:04:38|Czech Republic|  Hodonín|
# +---+-----------+-------------+--------------------+-------------------+--------------+---------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name| state|
# +---+-----------+-------------+--------------------+-------------------+------------+------+
# |111|          7|         Emil|Workout Leggins f...|2023-04-28 21:05:08|        Iran|Semnan|
# |112|          9|          Jox|          Fire Stick|2023-04-28 21:05:38|      Tuvalu|   Nui|
# +---+-----------+-------------+--------------------+-------------------+------------+------+
#
# +---+-----------+-------------+----------------+-------------------+------------+---------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|    state|
# +---+-----------+-------------+----------------+-------------------+------------+---------+
# |113|          8|      Maryina| Ninja Air Frier|2023-04-28 21:06:08|     Vietnam|Quảng Trị|
# |114|         11|       Emilia| Apple Iphone 14|2023-04-28 21:06:38|    Portugal|   Aveiro|
# +---+-----------+-------------+----------------+-------------------+------------+---------+
#
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|  country_name|               state|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
# |115|          1|       Johnny|        Creatine|2023-04-28 21:07:08|United Kingdom|London Borough of...|
# |116|         20|     JohnEric|      Fire Stick|2023-04-28 21:07:38|        Latvia|Aizkraukle Munici...|
# +---+-----------+-------------+----------------+-------------------+--------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|       state|
# +---+-----------+-------------+----------------+-------------------+------------+------------+
# |117|         13|        Mario|      Air Jordan|2023-04-28 21:08:08|       Sudan|  River Nile|
# |118|          3|      EmilyAn|     Bed Pillows|2023-04-28 21:08:38|     Belarus|Brest Region|
# +---+-----------+-------------+----------------+-------------------+------------+------------+
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|        state|
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
# |119|         19|    Johnathan|        Creatine|2023-04-28 21:09:08|      Taiwan|      Hsinchu|
# |120|         18|       Johvay| Ninja Air Frier|2023-04-28 21:09:38|     Lebanon|Mount Lebanon|
# +---+-----------+-------------+----------------+-------------------+------------+-------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# |121|          4|         John|            Roku|2023-04-28 21:10:08|      Guyana|Upper Takutu-Uppe...|
# |122|         13|        Mario|            Roku|2023-04-28 21:10:38|       Italy|             Tuscany|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|               state|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
# |123|          3|      EmilyAn| Apple Iphone 14|2023-04-28 21:11:08|      Bhutan|   Zhemgang District|
# |124|         15|       Martha|      Fire Stick|2023-04-28 21:11:38|        Iran|Chaharmahal and B...|
# +---+-----------+-------------+----------------+-------------------+------------+--------------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|      state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------+
# |125|         20|     JohnEric|      Fire Stick|2023-04-28 21:12:08|       Yemen|    Socotra|
# |126|         13|        Mario|        Creatine|2023-04-28 21:12:38|       Kenya|Trans Nzoia|
# +---+-----------+-------------+----------------+-------------------+------------+-----------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# |127|          9|          Jox|     Samsung Tab|2023-04-28 21:13:08|  Azerbaijan|   Tovuz District|
# |128|         14|       Mirtha| Ninja Air Frier|2023-04-28 21:13:38|   Guatemala|Quiché Department|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|            state|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
# |129|          9|          Jox|        Creatine|2023-04-28 21:14:08|     Finland|Päijänne Tavastia|
# |130|         15|       Martha|      Air Jordan|2023-04-28 21:14:38|        Mali| Koulikoro Region|
# +---+-----------+-------------+----------------+-------------------+------------+-----------------+
#
# +---+-----------+-------------+----------------+-------------------+------------+----------------+
# | id|customer_id|customer_name|product_searched|        search_date|country_name|           state|
# +---+-----------+-------------+----------------+-------------------+------------+----------------+
# |131|         10|        Emona|            Roku|2023-04-28 21:15:08|Saudi Arabia|Eastern Province|
# |132|          8|      Maryina|     Bed Pillows|2023-04-28 21:15:38|       Haiti|          Centre|
# +---+-----------+-------------+----------------+-------------------+------------+----------------+
#
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# | id|customer_id|customer_name|    product_searched|        search_date|country_name|              state|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
# |133|         13|        Mario|          Air Jordan|2023-04-28 21:16:08|   Indonesia|Nusa Tenggara Barat|
# |134|         10|        Emona|Workout Leggins f...|2023-04-28 21:16:38|Burkina Faso|      Séno Province|
# +---+-----------+-------------+--------------------+-------------------+------------+-------------------+
#
# +---+-----------+-------------+------------------+-------------------+------------+--------+
# | id|customer_id|customer_name|  product_searched|        search_date|country_name|   state|
# +---+-----------+-------------+------------------+-------------------+------------+--------+
# |135|         19|    Johnathan|        Air Jordan|2023-04-28 21:17:08|     Algeria|  Djanet|
# |136|         16|       Marius|Samsung Galaxy s22|2023-04-28 21:17:38|      Latvia|Valmiera|
# +---+-----------+-------------+------------------+-------------------+------------+--------+
